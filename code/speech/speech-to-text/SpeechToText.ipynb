# %% [markdown]
# ## Refer to the Speech to Text 3.0 Swagger documentation: https://develop.cris.ai/swagger/ui/index?urls.primaryName=Speech%20Services%20API%20v3.0#

# %%
from azure.storage.blob import BlobServiceClient

# %%
import requests
import json
import pandas as pd
import argparse
import time
import http.client, urllib.request, urllib.parse, urllib.error, base64

# %%
## Speech to Text region
region = "westeurope"

# %%
## Speech to Text - subscription key
SUBSCRIPTION_KEY = "621a0bbdfb69415aa0bdea7fae26539d"

# %%
## Storage Account connection string and SAS key
connect_str = 'DefaultEndpointsProtocol=https;AccountName=sttttsstorage;AccountKey=X/uI+nGAq5CBTfC3EF36uSjhK+xMGhuIBvFh9wN6Uw7p9vaBaIKIwyZiz0kEH2dAkFXUhgL8mG0L3oNxLxQGFg==;EndpointSuffix=core.windows.net'
SAS = '?sv=2021-06-08&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2022-12-02T20:10:47Z&st=2022-11-25T12:10:47Z&spr=https&sig=alTnZVBhDvhIWknjCCwaDkYtRel26%2FkHOKoTAI2E6iM%3D'

# %%
## storage account - account name and container name. This where we store the audio files
#container_name = "datamultiplevoices"
container_name = "kantaraudios"

account_name = "sttttsstorage"

# %%
## Speech to Text Endpoint for Transcriptions 

BaseURL ="https://" + region + ".api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/"
EndpointURL = "https://" + region + ".api.cognitive.microsoft.com/speechtotext/v3.0/endpoints/"

# %%
## Storage path
STORAGE_PATH="https://" + account_name + ".blob.core.windows.net/" + container_name + "/"

# %% [markdown]
# ## Prepare HTTP POST Request Body with associated Speech to Text properties

# %% [markdown]
#                 "customProperties": {
#                     "diarizationV3Enabled": true
#                 }

# %%
## Speech to Text - transcription properties
def bulkTranscription(blob_uri, blob_name):
    BD = """
            {
                "contentUrls": [ 
                    "__URL__"],
                "locale": "en-US",
                "displayName": "blob_name",
                "properties": {
                    "punctuationMode": "Automatic",
                    "profanityFilterMode": "Masked",
                    "wordLevelTimestampsEnabled": "False",
                    "diarizationEnabled" : "False"
                }

            }
            """
    BD = BD.replace("__URL__", URL)  
    BD = BD.replace("blob_name", blobname)
    return BD

# %% [markdown]
# ## Initialize HTTP POST request headers

# %%
headers = {"Ocp-Apim-Subscription-Key": SUBSCRIPTION_KEY}

# %% [markdown]
# ## Initialize the connection to our Blob storage account and container. Store the list of blobs in blob_list

# %%
blob_service_client = BlobServiceClient.from_connection_string(connect_str)
container_client = blob_service_client.get_container_client(container_name)
blob_list = container_client.list_blobs()

# %%
blob_list
# Out:
# <iterator object azure.core.paging.ItemPaged at 0x1cdaecbd250>

# %% [markdown]
# ## For every blob (audio file) in our storage account container call the Speech to Text REST API and transcribe the audio file

# %%
for blob in blob_list:
    print("\t" + blob.name)
    RECORDINGS_BLOB_URI = STORAGE_PATH + blob.name + SAS
    URL = RECORDINGS_BLOB_URI
    blobname = blob.name
    r = requests.post(BaseURL, headers=headers,data=bulkTranscription(URL,blobname))
    print(r.text)
    js = json.loads(r.text)
    print(js)
# Out:
# 	00000001_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/279ac850-6b01-4573-9667-b84099d7e16b",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/279ac850-6b01-4573-9667-b84099d7e16b/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:32Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:32Z",
#   "locale": "en-US",
#   "displayName": "00000001_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/279ac850-6b01-4573-9667-b84099d7e16b', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/279ac850-6b01-4573-9667-b84099d7e16b/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:32Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:32Z', 'locale': 'en-US', 'displayName': '00000001_silent_363L20-1.mpeg4'}
# 	00000001_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:33Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:33Z",
#   "locale": "en-US",
#   "displayName": "00000001_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:33Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:33Z', 'locale': 'en-US', 'displayName': '00000001_silent_392L20-1.mpeg4'}
# 	00000001_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/1523b659-109f-465c-9c89-83205dfc3b57",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/1523b659-109f-465c-9c89-83205dfc3b57/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:33Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:33Z",
#   "locale": "en-US",
#   "displayName": "00000001_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/1523b659-109f-465c-9c89-83205dfc3b57', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/1523b659-109f-465c-9c89-83205dfc3b57/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:33Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:33Z', 'locale': 'en-US', 'displayName': '00000001_silent_424L20-1.mpeg4'}
# 	00000001_silent_456L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/caf187a6-6c61-430f-96ff-34312bc82c66",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/caf187a6-6c61-430f-96ff-34312bc82c66/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:33Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:33Z",
#   "locale": "en-US",
#   "displayName": "00000001_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/caf187a6-6c61-430f-96ff-34312bc82c66', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/caf187a6-6c61-430f-96ff-34312bc82c66/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:33Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:33Z', 'locale': 'en-US', 'displayName': '00000001_silent_456L20-1.mpeg4'}
# 	00000001_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/df6ba978-d8a1-47d1-bf5a-6a6b77e53684",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/df6ba978-d8a1-47d1-bf5a-6a6b77e53684/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:33Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:33Z",
#   "locale": "en-US",
#   "displayName": "00000001_silent_485L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/df6ba978-d8a1-47d1-bf5a-6a6b77e53684', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/df6ba978-d8a1-47d1-bf5a-6a6b77e53684/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:33Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:33Z', 'locale': 'en-US', 'displayName': '00000001_silent_485L20-1.mpeg4'}
# 	00000002_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27d8cfb7-acae-4631-b110-85597301167b",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27d8cfb7-acae-4631-b110-85597301167b/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:33Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:33Z",
#   "locale": "en-US",
#   "displayName": "00000002_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27d8cfb7-acae-4631-b110-85597301167b', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27d8cfb7-acae-4631-b110-85597301167b/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:33Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:33Z', 'locale': 'en-US', 'displayName': '00000002_silent_363L20-1.mpeg4'}
# 	00000002_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/31fc28c4-56c5-4c53-b4a1-2948392b34c5",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/31fc28c4-56c5-4c53-b4a1-2948392b34c5/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:33Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:33Z",
#   "locale": "en-US",
#   "displayName": "00000002_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/31fc28c4-56c5-4c53-b4a1-2948392b34c5', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/31fc28c4-56c5-4c53-b4a1-2948392b34c5/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:33Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:33Z', 'locale': 'en-US', 'displayName': '00000002_silent_392L20-1.mpeg4'}
# 	00000002_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7aa1a814-f21d-4d68-ae72-fa906fca1ef1",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7aa1a814-f21d-4d68-ae72-fa906fca1ef1/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:34Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:34Z",
#   "locale": "en-US",
#   "displayName": "00000002_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7aa1a814-f21d-4d68-ae72-fa906fca1ef1', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7aa1a814-f21d-4d68-ae72-fa906fca1ef1/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:34Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:34Z', 'locale': 'en-US', 'displayName': '00000002_silent_424L20-1.mpeg4'}
# 	00000002_silent_456L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0a9e5043-c7a2-47da-a250-b2a83607af7a",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0a9e5043-c7a2-47da-a250-b2a83607af7a/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:34Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:34Z",
#   "locale": "en-US",
#   "displayName": "00000002_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0a9e5043-c7a2-47da-a250-b2a83607af7a', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0a9e5043-c7a2-47da-a250-b2a83607af7a/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:34Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:34Z', 'locale': 'en-US', 'displayName': '00000002_silent_456L20-1.mpeg4'}
# 	00000002_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/f45e63b7-fe9b-47b1-9932-b005561766b7",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/f45e63b7-fe9b-47b1-9932-b005561766b7/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:34Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:34Z",
#   "locale": "en-US",
#   "displayName": "00000002_silent_485L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/f45e63b7-fe9b-47b1-9932-b005561766b7', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/f45e63b7-fe9b-47b1-9932-b005561766b7/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:34Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:34Z', 'locale': 'en-US', 'displayName': '00000002_silent_485L20-1.mpeg4'}
# 	00000003_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/3a6afd17-7450-42d8-8274-1612840de9ee",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/3a6afd17-7450-42d8-8274-1612840de9ee/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:34Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:34Z",
#   "locale": "en-US",
#   "displayName": "00000003_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/3a6afd17-7450-42d8-8274-1612840de9ee', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/3a6afd17-7450-42d8-8274-1612840de9ee/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:34Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:34Z', 'locale': 'en-US', 'displayName': '00000003_silent_363L20-1.mpeg4'}
# 	00000003_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/197b9a96-4aae-4edc-8445-3ce0934a18d5",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/197b9a96-4aae-4edc-8445-3ce0934a18d5/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:34Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:34Z",
#   "locale": "en-US",
#   "displayName": "00000003_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/197b9a96-4aae-4edc-8445-3ce0934a18d5', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/197b9a96-4aae-4edc-8445-3ce0934a18d5/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:34Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:34Z', 'locale': 'en-US', 'displayName': '00000003_silent_392L20-1.mpeg4'}
# 	00000003_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d659e794-f8fc-4737-96d2-60e42ac1c4aa",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d659e794-f8fc-4737-96d2-60e42ac1c4aa/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:35Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:35Z",
#   "locale": "en-US",
#   "displayName": "00000003_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d659e794-f8fc-4737-96d2-60e42ac1c4aa', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d659e794-f8fc-4737-96d2-60e42ac1c4aa/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:35Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:35Z', 'locale': 'en-US', 'displayName': '00000003_silent_424L20-1.mpeg4'}
# 	00000003_silent_456L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/75e7c463-37cf-4a49-8431-87429595c73a",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/75e7c463-37cf-4a49-8431-87429595c73a/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:35Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:35Z",
#   "locale": "en-US",
#   "displayName": "00000003_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/75e7c463-37cf-4a49-8431-87429595c73a', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/75e7c463-37cf-4a49-8431-87429595c73a/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:35Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:35Z', 'locale': 'en-US', 'displayName': '00000003_silent_456L20-1.mpeg4'}
# 	00000003_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2edf986f-85bc-41a6-8ce9-830b1057da9d",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2edf986f-85bc-41a6-8ce9-830b1057da9d/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:35Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:35Z",
#   "locale": "en-US",
#   "displayName": "00000003_silent_485L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2edf986f-85bc-41a6-8ce9-830b1057da9d', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2edf986f-85bc-41a6-8ce9-830b1057da9d/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:35Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:35Z', 'locale': 'en-US', 'displayName': '00000003_silent_485L20-1.mpeg4'}
# 	00000004_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/bfafb3f5-6754-4924-a2af-7df9b50ef35c",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/bfafb3f5-6754-4924-a2af-7df9b50ef35c/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:35Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:35Z",
#   "locale": "en-US",
#   "displayName": "00000004_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/bfafb3f5-6754-4924-a2af-7df9b50ef35c', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/bfafb3f5-6754-4924-a2af-7df9b50ef35c/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:35Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:35Z', 'locale': 'en-US', 'displayName': '00000004_silent_363L20-1.mpeg4'}
# 	00000004_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/c037ba1e-1e8e-4ca0-82a5-ddab676463e6",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/c037ba1e-1e8e-4ca0-82a5-ddab676463e6/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:35Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:35Z",
#   "locale": "en-US",
#   "displayName": "00000004_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/c037ba1e-1e8e-4ca0-82a5-ddab676463e6', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/c037ba1e-1e8e-4ca0-82a5-ddab676463e6/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:35Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:35Z', 'locale': 'en-US', 'displayName': '00000004_silent_392L20-1.mpeg4'}
# 	00000004_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/01c8f3e0-ff43-4274-8966-96e035e6d955",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/01c8f3e0-ff43-4274-8966-96e035e6d955/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:35Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:35Z",
#   "locale": "en-US",
#   "displayName": "00000004_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/01c8f3e0-ff43-4274-8966-96e035e6d955', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/01c8f3e0-ff43-4274-8966-96e035e6d955/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:35Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:35Z', 'locale': 'en-US', 'displayName': '00000004_silent_424L20-1.mpeg4'}
# 	00000004_silent_456L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a13f924b-71da-4c83-aaaa-96e367c9e6f4",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a13f924b-71da-4c83-aaaa-96e367c9e6f4/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:36Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:36Z",
#   "locale": "en-US",
#   "displayName": "00000004_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a13f924b-71da-4c83-aaaa-96e367c9e6f4', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a13f924b-71da-4c83-aaaa-96e367c9e6f4/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:36Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:36Z', 'locale': 'en-US', 'displayName': '00000004_silent_456L20-1.mpeg4'}
# 	00000004_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a0732d63-48db-4152-bbb5-bb8a95b126fc",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a0732d63-48db-4152-bbb5-bb8a95b126fc/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:36Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:36Z",
#   "locale": "en-US",
#   "displayName": "00000004_silent_485L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a0732d63-48db-4152-bbb5-bb8a95b126fc', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a0732d63-48db-4152-bbb5-bb8a95b126fc/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:36Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:36Z', 'locale': 'en-US', 'displayName': '00000004_silent_485L20-1.mpeg4'}
# 	00000005_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/49417459-6d15-459d-8e63-70166a66aa14",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/49417459-6d15-459d-8e63-70166a66aa14/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:36Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:36Z",
#   "locale": "en-US",
#   "displayName": "00000005_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/49417459-6d15-459d-8e63-70166a66aa14', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/49417459-6d15-459d-8e63-70166a66aa14/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:36Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:36Z', 'locale': 'en-US', 'displayName': '00000005_silent_363L20-1.mpeg4'}
# 	00000005_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0bfc99c4-8a95-4f6e-beae-61fa68e53634",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0bfc99c4-8a95-4f6e-beae-61fa68e53634/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:36Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:36Z",
#   "locale": "en-US",
#   "displayName": "00000005_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0bfc99c4-8a95-4f6e-beae-61fa68e53634', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/0bfc99c4-8a95-4f6e-beae-61fa68e53634/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:36Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:36Z', 'locale': 'en-US', 'displayName': '00000005_silent_392L20-1.mpeg4'}
# 	00000005_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a8a83dbe-050c-43f0-970f-8b314594290e",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a8a83dbe-050c-43f0-970f-8b314594290e/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:36Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:36Z",
#   "locale": "en-US",
#   "displayName": "00000005_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a8a83dbe-050c-43f0-970f-8b314594290e', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a8a83dbe-050c-43f0-970f-8b314594290e/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:36Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:36Z', 'locale': 'en-US', 'displayName': '00000005_silent_424L20-1.mpeg4'}
# 	00000005_silent_456L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27c5878e-e3f2-4666-a025-db3545781c01",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27c5878e-e3f2-4666-a025-db3545781c01/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:37Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:37Z",
#   "locale": "en-US",
#   "displayName": "00000005_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27c5878e-e3f2-4666-a025-db3545781c01', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/27c5878e-e3f2-4666-a025-db3545781c01/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:37Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:37Z', 'locale': 'en-US', 'displayName': '00000005_silent_456L20-1.mpeg4'}
# 	00000005_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a6a61c24-ea46-45f3-b2f2-f86f9b911de8",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a6a61c24-ea46-45f3-b2f2-f86f9b911de8/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:37Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:37Z",
#   "locale": "en-US",
#   "displayName": "00000005_silent_485L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a6a61c24-ea46-45f3-b2f2-f86f9b911de8', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/a6a61c24-ea46-45f3-b2f2-f86f9b911de8/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:37Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:37Z', 'locale': 'en-US', 'displayName': '00000005_silent_485L20-1.mpeg4'}
# 	00000006_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/03acc157-e339-4c0f-9fb8-18efd31f0416",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/03acc157-e339-4c0f-9fb8-18efd31f0416/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:37Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:37Z",
#   "locale": "en-US",
#   "displayName": "00000006_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/03acc157-e339-4c0f-9fb8-18efd31f0416', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/03acc157-e339-4c0f-9fb8-18efd31f0416/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:37Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:37Z', 'locale': 'en-US', 'displayName': '00000006_silent_363L20-1.mpeg4'}
# 	00000006_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/71f50c82-fbc7-4ece-b7a0-cf3e0ee7fbd5",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/71f50c82-fbc7-4ece-b7a0-cf3e0ee7fbd5/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:37Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:37Z",
#   "locale": "en-US",
#   "displayName": "00000006_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/71f50c82-fbc7-4ece-b7a0-cf3e0ee7fbd5', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/71f50c82-fbc7-4ece-b7a0-cf3e0ee7fbd5/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:37Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:37Z', 'locale': 'en-US', 'displayName': '00000006_silent_392L20-1.mpeg4'}
# 	00000006_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/e9a42c44-449b-4e58-bc0a-d55b897d152a",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/e9a42c44-449b-4e58-bc0a-d55b897d152a/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:37Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:37Z",
#   "locale": "en-US",
#   "displayName": "00000006_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/e9a42c44-449b-4e58-bc0a-d55b897d152a', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/e9a42c44-449b-4e58-bc0a-d55b897d152a/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:37Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:37Z', 'locale': 'en-US', 'displayName': '00000006_silent_424L20-1.mpeg4'}
# 	00000006_silent_456L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/111c1087-9672-44fa-b2ba-e4a44f7434ca",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/111c1087-9672-44fa-b2ba-e4a44f7434ca/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:38Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:38Z",
#   "locale": "en-US",
#   "displayName": "00000006_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/111c1087-9672-44fa-b2ba-e4a44f7434ca', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/111c1087-9672-44fa-b2ba-e4a44f7434ca/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:38Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:38Z', 'locale': 'en-US', 'displayName': '00000006_silent_456L20-1.mpeg4'}
# 	00000006_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d3a282a4-825f-4dc4-a593-b0a031cb357a",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d3a282a4-825f-4dc4-a593-b0a031cb357a/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:38Z",
#   "status": "NotStarted",
# ...
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/6f1c821a-1444-4133-8c5a-9ca880de1b8c/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:46Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:46Z",
#   "locale": "en-US",
#   "displayName": "00000015_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/6f1c821a-1444-4133-8c5a-9ca880de1b8c', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/6f1c821a-1444-4133-8c5a-9ca880de1b8c/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:46Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:46Z', 'locale': 'en-US', 'displayName': '00000015_silent_456L20-1.mpeg4'}
# 	00000015_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/b44bf674-f73b-4e69-a291-f679696c50f9",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/b44bf674-f73b-4e69-a291-f679696c50f9/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:46Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:46Z",
#   "locale": "en-US",
#   "displayName": "00000015_silent_485L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/b44bf674-f73b-4e69-a291-f679696c50f9', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/b44bf674-f73b-4e69-a291-f679696c50f9/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:46Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:46Z', 'locale': 'en-US', 'displayName': '00000015_silent_485L20-1.mpeg4'}
# 	00000016_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7f5b04dd-41c0-49d8-b1f2-88803b3d7cf9",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7f5b04dd-41c0-49d8-b1f2-88803b3d7cf9/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:47Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:47Z",
#   "locale": "en-US",
#   "displayName": "00000016_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7f5b04dd-41c0-49d8-b1f2-88803b3d7cf9', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/7f5b04dd-41c0-49d8-b1f2-88803b3d7cf9/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:47Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:47Z', 'locale': 'en-US', 'displayName': '00000016_silent_363L20-1.mpeg4'}
# 	00000016_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/ec7b313d-7604-46d4-ba83-8697e6215bb4",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/ec7b313d-7604-46d4-ba83-8697e6215bb4/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:47Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:47Z",
#   "locale": "en-US",
#   "displayName": "00000016_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/ec7b313d-7604-46d4-ba83-8697e6215bb4', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/ec7b313d-7604-46d4-ba83-8697e6215bb4/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:47Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:47Z', 'locale': 'en-US', 'displayName': '00000016_silent_392L20-1.mpeg4'}
# 	00000016_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2846d87d-3f24-4443-aeb7-5623357f5fbd",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2846d87d-3f24-4443-aeb7-5623357f5fbd/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:47Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:47Z",
#   "locale": "en-US",
#   "displayName": "00000016_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2846d87d-3f24-4443-aeb7-5623357f5fbd', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2846d87d-3f24-4443-aeb7-5623357f5fbd/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:47Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:47Z', 'locale': 'en-US', 'displayName': '00000016_silent_424L20-1.mpeg4'}
# 	00000016_silent_456L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2b4c9387-c45c-4af5-a6cb-d9a9fb764fd0",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2b4c9387-c45c-4af5-a6cb-d9a9fb764fd0/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:47Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:47Z",
#   "locale": "en-US",
#   "displayName": "00000016_silent_456L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2b4c9387-c45c-4af5-a6cb-d9a9fb764fd0', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/2b4c9387-c45c-4af5-a6cb-d9a9fb764fd0/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:47Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:47Z', 'locale': 'en-US', 'displayName': '00000016_silent_456L20-1.mpeg4'}
# 	00000016_silent_485L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d88a0aeb-51cf-46ef-be4e-127f51b88918",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d88a0aeb-51cf-46ef-be4e-127f51b88918/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:48Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:48Z",
#   "locale": "en-US",
#   "displayName": "00000016_silent_485L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d88a0aeb-51cf-46ef-be4e-127f51b88918', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d88a0aeb-51cf-46ef-be4e-127f51b88918/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:48Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:48Z', 'locale': 'en-US', 'displayName': '00000016_silent_485L20-1.mpeg4'}
# 	00000017_silent_363L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d6511148-067b-45d7-974a-ce9a87b42ed7",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d6511148-067b-45d7-974a-ce9a87b42ed7/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:48Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:48Z",
#   "locale": "en-US",
#   "displayName": "00000017_silent_363L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d6511148-067b-45d7-974a-ce9a87b42ed7', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/d6511148-067b-45d7-974a-ce9a87b42ed7/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:48Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:48Z', 'locale': 'en-US', 'displayName': '00000017_silent_363L20-1.mpeg4'}
# 	00000017_silent_392L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/cbefbce3-fe41-4fbe-83c9-af15cb693718",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/cbefbce3-fe41-4fbe-83c9-af15cb693718/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:48Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:48Z",
#   "locale": "en-US",
#   "displayName": "00000017_silent_392L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/cbefbce3-fe41-4fbe-83c9-af15cb693718', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/cbefbce3-fe41-4fbe-83c9-af15cb693718/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:48Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:48Z', 'locale': 'en-US', 'displayName': '00000017_silent_392L20-1.mpeg4'}
# 	00000017_silent_424L20-1.mpeg4
# {
#   "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/94227e02-3158-47c3-be3d-54789a34c6b4",
#   "model": {
#     "self": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597"
#   },
#   "links": {
#     "files": "https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/94227e02-3158-47c3-be3d-54789a34c6b4/files"
#   },
#   "properties": {
#     "diarizationEnabled": false,
#     "wordLevelTimestampsEnabled": false,
#     "channels": [
#       0,
#       1
#     ],
#     "punctuationMode": "Automatic",
#     "profanityFilterMode": "Masked"
#   },
#   "lastActionDateTime": "2022-11-25T12:42:48Z",
#   "status": "NotStarted",
#   "createdDateTime": "2022-11-25T12:42:48Z",
#   "locale": "en-US",
#   "displayName": "00000017_silent_424L20-1.mpeg4"
# }
# {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/94227e02-3158-47c3-be3d-54789a34c6b4', 'model': {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/models/base/89aacd27-972c-4042-b91d-6cd544841597'}, 'links': {'files': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/94227e02-3158-47c3-be3d-54789a34c6b4/files'}, 'properties': {'diarizationEnabled': False, 'wordLevelTimestampsEnabled': False, 'channels': [0, 1], 'punctuationMode': 'Automatic', 'profanityFilterMode': 'Masked'}, 'lastActionDateTime': '2022-11-25T12:42:48Z', 'status': 'NotStarted', 'createdDateTime': '2022-11-25T12:42:48Z', 'locale': 'en-US', 'displayName': '00000017_silent_424L20-1.mpeg4'}

# %% [markdown]
# ## List all transcriptions in either of the following states (Not Started, Running, Succeeded, Failed)

# %%
def listAllTranscriptions() :
    import datetime
    df = pd.DataFrame(columns=["id","name", "status","createdDateTime","lastActionDateTime","CallDuration"])
    headers = {"Ocp-Apim-Subscription-Key": SUBSCRIPTION_KEY}
    r = requests.get(BaseURL, headers=headers)
    js = json.loads(r.text)
    #print(js)
    for TR in js['values']:
        if TR["status"] not in ("Succeeded")  :
            Dur="-"
        else :
            Dur = TR["properties"]["duration"]
        if TR["displayName"] not in ("Accuracy Test Transcription"):

            df = df.append({
             "id":                  TR["self"].split('/')[-1],
             "name":                TR["displayName"],
             "status":              TR["status"],
             "createdDateTime":     datetime.datetime.strptime(TR["createdDateTime"],"%Y-%m-%dT%H:%M:%SZ"),            
             "lastActionDateTime":  datetime.datetime.strptime(TR["lastActionDateTime"],"%Y-%m-%dT%H:%M:%SZ"),
             "CallDuration":            Dur      
              }, ignore_index=True)
            df["ProcTime"] = df["lastActionDateTime"] - df["createdDateTime"]

    return(df)

# %%
listAllTranscriptions()
# Out:
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
#                                       id                            name  \
# 0   279ac850-6b01-4573-9667-b84099d7e16b  00000001_silent_363L20-1.mpeg4
# 1   84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb  00000001_silent_392L20-1.mpeg4
# 2   1523b659-109f-465c-9c89-83205dfc3b57  00000001_silent_424L20-1.mpeg4
# 3   caf187a6-6c61-430f-96ff-34312bc82c66  00000001_silent_456L20-1.mpeg4
# 4   df6ba978-d8a1-47d1-bf5a-6a6b77e53684  00000001_silent_485L20-1.mpeg4
# ..                                   ...                             ...
# 73  2b4c9387-c45c-4af5-a6cb-d9a9fb764fd0  00000016_silent_456L20-1.mpeg4
# 74  d88a0aeb-51cf-46ef-be4e-127f51b88918  00000016_silent_485L20-1.mpeg4
# 75  d6511148-067b-45d7-974a-ce9a87b42ed7  00000017_silent_363L20-1.mpeg4
# 76  cbefbce3-fe41-4fbe-83c9-af15cb693718  00000017_silent_392L20-1.mpeg4
# 77  94227e02-3158-47c3-be3d-54789a34c6b4  00000017_silent_424L20-1.mpeg4
#
#        status      createdDateTime   lastActionDateTime CallDuration  \
# 0   Succeeded  2022-11-25 12:42:32  2022-11-25 12:42:54        PT14S
# 1   Succeeded  2022-11-25 12:42:33  2022-11-25 12:44:35       PT1M3S
# 2   Succeeded  2022-11-25 12:42:33  2022-11-25 12:43:13        PT33S
# 3   Succeeded  2022-11-25 12:42:33  2022-11-25 12:43:38        PT30S
# 4   Succeeded  2022-11-25 12:42:33  2022-11-25 12:43:27      PT1M15S
# ..        ...                  ...                  ...          ...
# 73  Succeeded  2022-11-25 12:42:47  2022-11-25 12:43:27        PT15S
# 74  Succeeded  2022-11-25 12:42:48  2022-11-25 12:43:21         PT5S
# 75  Succeeded  2022-11-25 12:42:48  2022-11-25 12:43:22        PT13S
# 76  Succeeded  2022-11-25 12:42:48  2022-11-25 12:43:49        PT26S
# 77  Succeeded  2022-11-25 12:42:48  2022-11-25 12:43:36        PT14S
#
#           ProcTime
# 0  0 days 00:00:22
# 1  0 days 00:02:02
# 2  0 days 00:00:40
# 3  0 days 00:01:05
# 4  0 days 00:00:54
# ..             ...
# 73 0 days 00:00:40
# 74 0 days 00:00:33
# 75 0 days 00:00:34
# 76 0 days 00:01:01
# 77 0 days 00:00:48
#
# [78 rows x 7 columns]

# %%
transcriptions = listAllTranscriptions()
# Out:
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_57288\941921940.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({

# %% [markdown]
# ## Go through each transcription that finished and is in "Succeeded" status and obtain the json output of the transcription. Save the json file locally

# %%
headers = {
    # Request headers
    'Ocp-Apim-Subscription-Key': SUBSCRIPTION_KEY,
}

params = urllib.parse.urlencode({
    # Request parameters
})

# %%
for index, row in transcriptions.iterrows():
    if row["status"] in ("Succeeded"):
        conn = http.client.HTTPSConnection(region + '.api.cognitive.microsoft.com')
        conn.request("GET", "/speechtotext/v3.0/transcriptions/" + row["id"] + "/files?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        print(json.loads(data))
        jsonobj = json.loads(data)
        for val in jsonobj['values']:
            if val['kind'] == 'Transcription':
                contentUrl = val['links']['contentUrl']
        print(contentUrl)
        r = requests.get(contentUrl, headers=headers)
        print(r.text)
        json_text = json.loads(r.text)
        with open(row['name']+"_"+row['id']+".json", 'w', encoding='utf-8') as f:
            json.dump(json_text, f, ensure_ascii=False, indent=4)
    elif row["status"] in ("Failed"):
        conn = http.client.HTTPSConnection(region + '.api.cognitive.microsoft.com')
        conn.request("GET", "/speechtotext/v3.0/transcriptions/" + row["id"] + "/files?%s" % params, "{body}", headers)
        response = conn.getresponse()
        data = response.read()
        print(json.loads(data))
# Out:
# {'values': [{'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/279ac850-6b01-4573-9667-b84099d7e16b/files/f1843833-5fca-4c95-81bc-325299ba5081', 'name': 'contenturl_0.json', 'kind': 'Transcription', 'properties': {'size': 6617}, 'createdDateTime': '2022-11-25T12:42:54Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/279ac850-6b01-4573-9667-b84099d7e16b_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A45Z&se=2022-11-26T00%3A59%3A45Z&sr=b&sp=rl&sig=e82khLkCOO2gJAV%2BzoYbtZYyGrigJK1TNxm2UZfcTA8%3D'}}, {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/279ac850-6b01-4573-9667-b84099d7e16b/files/bbbbf272-ceb7-4d90-bb16-23092a25638b', 'name': 'report.json', 'kind': 'TranscriptionReport', 'properties': {'size': 399}, 'createdDateTime': '2022-11-25T12:42:54Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/279ac850-6b01-4573-9667-b84099d7e16b_report.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A45Z&se=2022-11-26T00%3A59%3A45Z&sr=b&sp=rl&sig=3EBDQ86Q6%2BERVQYAKUHAH%2BD1MK%2B6Ozln%2BOBJIIeGXvs%3D'}}]}
# https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/279ac850-6b01-4573-9667-b84099d7e16b_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A45Z&se=2022-11-26T00%3A59%3A45Z&sr=b&sp=rl&sig=e82khLkCOO2gJAV%2BzoYbtZYyGrigJK1TNxm2UZfcTA8%3D
# {
#   "source": "https://sttttsstorage.blob.core.windows.net/kantaraudios/00000001_silent_363L20-1.mpeg4?sv=2021-06-08&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2022-12-02T20:10:47Z&st=2022-11-25T12:10:47Z&spr=https&sig=alTnZVBhDvhIWknjCCwaDkYtRel26%2FkHOKoTAI2E6iM%3D",
#   "timestamp": "2022-11-25T12:42:53Z",
#   "durationInTicks": 149800000,
#   "duration": "PT14.98S",
#   "combinedRecognizedPhrases": [
#     {
#       "channel": 0,
#       "lexical": "continue or so uh could you please tell me which of these eight groups you fall into",
#       "itn": "continue or so uh could you please tell me which of these eight groups you fall into",
#       "maskedITN": "continue or so uh could you please tell me which of these eight groups you fall into",
#       "display": "Continue. Or so. Uh, could you please tell me which of these eight groups you fall into?"
#     }
#   ],
#   "recognizedPhrases": [
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT0.2S",
#       "duration": "PT0.85S",
#       "offsetInTicks": 2000000.0,
#       "durationInTicks": 8500000.0,
#       "nBest": [
#         {
#           "confidence": 0.5613578,
#           "lexical": "continue",
#           "itn": "continue",
#           "maskedITN": "continue",
#           "display": "Continue."
#         },
#         {
#           "confidence": 0.23491065,
#           "lexical": "continue to",
#           "itn": "continue to",
#           "maskedITN": "continue to",
#           "display": "continue to"
#         },
#         {
#           "confidence": 0.074424595,
#           "lexical": "continuing",
#           "itn": "continuing",
#           "maskedITN": "continuing",
#           "display": "continuing"
#         },
#         {
#           "confidence": 0.099001765,
#           "lexical": "continuum",
#           "itn": "continuum",
#           "maskedITN": "continuum",
#           "display": "continuum"
#         },
#         {
#           "confidence": 0.100946754,
#           "lexical": "continued",
#           "itn": "continued",
#           "maskedITN": "continued",
#           "display": "continued"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT1.9S",
#       "duration": "PT0.62S",
#       "offsetInTicks": 19000000.0,
#       "durationInTicks": 6200000.0,
#       "nBest": [
#         {
#           "confidence": 0.41856167,
#           "lexical": "or so",
#           "itn": "or so",
#           "maskedITN": "or so",
#           "display": "Or so."
#         },
#         {
#           "confidence": 0.061306775,
#           "lexical": "awesome",
#           "itn": "awesome",
#           "maskedITN": "awesome",
#           "display": "awesome"
#         },
#         {
#           "confidence": 0.101723075,
#           "lexical": "also",
#           "itn": "also",
#           "maskedITN": "also",
#           "display": "also"
#         },
#         {
#           "confidence": 0.5684762,
#           "lexical": "alright so",
#           "itn": "alright so",
#           "maskedITN": "alright so",
#           "display": "alright so"
#         },
#         {
#           "confidence": 0.5484171,
#           "lexical": "what's your name",
#           "itn": "what's your name",
#           "maskedITN": "what's your name",
#           "display": "what's your name"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT4.82S",
#       "duration": "PT3.59S",
#       "offsetInTicks": 48200000.0,
#       "durationInTicks": 35900000.0,
#       "nBest": [
#         {
#           "confidence": 0.8205721,
#           "lexical": "uh could you please tell me which of these eight groups you fall into",
#           "itn": "uh could you please tell me which of these eight groups you fall into",
#           "maskedITN": "uh could you please tell me which of these eight groups you fall into",
#           "display": "Uh, could you please tell me which of these eight groups you fall into?"
#         },
#         {
#           "confidence": 0.80448407,
#           "lexical": "uh could you please tell me which of these eight groups we fall into",
#           "itn": "uh could you please tell me which of these eight groups we fall into",
#           "maskedITN": "uh could you please tell me which of these eight groups we fall into",
#           "display": "uh could you please tell me which of these eight groups we fall into"
#         },
#         {
#           "confidence": 0.80457044,
#           "lexical": "uh could you please tell me which of these eight groups they fall into",
#           "itn": "uh could you please tell me which of these eight groups they fall into",
#           "maskedITN": "uh could you please tell me which of these eight groups they fall into",
#           "display": "uh could you please tell me which of these eight groups they fall into"
#         },
#         {
#           "confidence": 0.7935496,
#           "lexical": "uh could you please tell me which of these eight groups you'll fall into",
#           "itn": "uh could you please tell me which of these eight groups you'll fall into",
#           "maskedITN": "uh could you please tell me which of these eight groups you'll fall into",
#           "display": "uh could you please tell me which of these eight groups you'll fall into"
#         },
#         {
#           "confidence": 0.747526,
#           "lexical": "uh could you please tell me which of these eight groups fall into",
#           "itn": "uh could you please tell me which of these eight groups fall into",
#           "maskedITN": "uh could you please tell me which of these eight groups fall into",
#           "display": "uh could you please tell me which of these eight groups fall into"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT12.6S",
#       "duration": "PT2.38S",
#       "offsetInTicks": 126000000.0,
#       "durationInTicks": 23800000.0,
#       "nBest": [
#         {
#           "confidence": 0.0,
#           "lexical": "",
#           "itn": "",
#           "maskedITN": "",
#           "display": ""
#         },
#         {
#           "confidence": 0.7143837,
#           "lexical": "no",
#           "itn": "no",
#           "maskedITN": "no",
#           "display": "no"
#         },
#         {
#           "confidence": 0.6148661,
#           "lexical": "hey",
#           "itn": "hey",
#           "maskedITN": "hey",
#           "display": "hey"
#         },
#         {
#           "confidence": 0.48244983,
#           "lexical": "yeah",
#           "itn": "yeah",
#           "maskedITN": "yeah",
#           "display": "yeah"
#         },
#         {
#           "confidence": 0.63117355,
#           "lexical": "oh",
#           "itn": "oh",
#           "maskedITN": "oh",
#           "display": "oh"
#         }
#       ]
#     }
#   ]
# }
# {'values': [{'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb/files/6e3e7f6a-d11f-472d-bf98-8bc7e08d6f71', 'name': 'contenturl_0.json', 'kind': 'Transcription', 'properties': {'size': 27213}, 'createdDateTime': '2022-11-25T12:44:35Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A46Z&se=2022-11-26T00%3A59%3A46Z&sr=b&sp=rl&sig=GD3qiQioBLzcQXIA6jJaQzzj9EGLNqHCMECs%2BuJXtfE%3D'}}, {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb/files/811e4531-61cd-489f-a56b-6de9934b153f', 'name': 'report.json', 'kind': 'TranscriptionReport', 'properties': {'size': 399}, 'createdDateTime': '2022-11-25T12:44:35Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb_report.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A46Z&se=2022-11-26T00%3A59%3A46Z&sr=b&sp=rl&sig=bHIzOnvFR6lS5E8fJUvHrHeTtZ71oqrDyNaJTB0wCWI%3D'}}]}
# https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/84a9ca5d-1c7b-4098-89c4-d9fcd9220ecb_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A46Z&se=2022-11-26T00%3A59%3A46Z&sr=b&sp=rl&sig=GD3qiQioBLzcQXIA6jJaQzzj9EGLNqHCMECs%2BuJXtfE%3D
# {
#   "source": "https://sttttsstorage.blob.core.windows.net/kantaraudios/00000001_silent_392L20-1.mpeg4?sv=2021-06-08&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2022-12-02T20:10:47Z&st=2022-11-25T12:10:47Z&spr=https&sig=alTnZVBhDvhIWknjCCwaDkYtRel26%2FkHOKoTAI2E6iM%3D",
#   "timestamp": "2022-11-25T12:44:35Z",
#   "durationInTicks": 638800000,
#   "duration": "PT1M3.88S",
#   "combinedRecognizedPhrases": [
#     {
#       "channel": 0,
#       "lexical": "overall i'll read through three short stories it's OK so hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe cornell strongly agree somewhat agree any common let's see i'm OK yeah it's not strongly agree somewhat agree that'd be a lot and as i am there and you will pay it's OK so you apply you apply to every every question now compared to choices you strongly agree somewhat agree boca chica hachi you could do it's OK i'm not gonna come on you do it it's OK so have a you're missing official like demand you",
#       "itn": "overall i'll read through three short stories it's OK so hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe cornell strongly agree somewhat agree any common let's see i'm OK yeah it's not strongly agree somewhat agree that'd be a lot and as i am there and you will pay it's OK so you apply you apply to every every question now compared to choices you strongly agree somewhat agree boca chica hachi you could do it's OK i'm not gonna come on you do it it's OK so have a you're missing official like demand you",
#       "maskedITN": "overall i'll read through three short stories it's ok so hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe cornell strongly agree somewhat agree any common let's see i'm ok yeah it's not strongly agree somewhat agree that'd be a lot and as i am there and you will pay it's ok so you apply you apply to every every question now compared to choices you strongly agree somewhat agree boca chica hachi you could do it's ok i'm not gonna come on you do it it's ok so have a you're missing official like demand you",
#       "display": "Overall, I'll read through three short stories. It's OK so. Hi, I'm busy and there is only a Kwanzaa. Do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe? Cornell strongly agree somewhat agree. Any common? Let's see, I'm. OK. Yeah. It's not strongly agree, somewhat agree. That'd be a lot. And as I am there. And you will pay. It's OK. So you apply. You apply to every every question. Now, compared to choices, you strongly agree. Somewhat agree. Boca Chica hachi. You could do. It's OK. I'm not gonna come on. You do it. It's OK. So have a you're missing official like demand you."
#     }
#   ],
#   "recognizedPhrases": [
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT0.6S",
#       "duration": "PT4.09S",
#       "offsetInTicks": 6000000.0,
#       "durationInTicks": 40900000.0,
#       "nBest": [
#         {
#           "confidence": 0.544463,
#           "lexical": "overall i'll read through three short stories",
#           "itn": "overall i'll read through three short stories",
#           "maskedITN": "overall i'll read through three short stories",
#           "display": "Overall, I'll read through three short stories."
#         },
#         {
#           "confidence": 0.49424967,
#           "lexical": "memory overall i'll read through three short stories",
#           "itn": "memory overall i'll read through three short stories",
#           "maskedITN": "memory overall i'll read through three short stories",
#           "display": "memory overall i'll read through three short stories"
#         },
#         {
#           "confidence": 0.56987864,
#           "lexical": "overall i love you i'll read through three short stories",
#           "itn": "overall i love you i'll read through three short stories",
#           "maskedITN": "overall i love you i'll read through three short stories",
#           "display": "overall i love you i'll read through three short stories"
#         },
#         {
#           "confidence": 0.5202738,
#           "lexical": "mayberry overall i'll read through three short stories",
#           "itn": "mayberry overall i'll read through three short stories",
#           "maskedITN": "mayberry overall i'll read through three short stories",
#           "display": "mayberry overall i'll read through three short stories"
#         },
#         {
#           "confidence": 0.5222291,
#           "lexical": "memory overall i love you i'll read through three short stories",
#           "itn": "memory overall i love you i'll read through three short stories",
#           "maskedITN": "memory overall i love you i'll read through three short stories",
#           "display": "memory overall i love you i'll read through three short stories"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT6.21S",
#       "duration": "PT1.03S",
#       "offsetInTicks": 62100000.0,
#       "durationInTicks": 10300000.0,
#       "nBest": [
#         {
#           "confidence": 0.5707301,
#           "lexical": "it's OK so",
#           "itn": "it's OK so",
#           "maskedITN": "it's ok so",
#           "display": "It's OK so."
#         },
#         {
#           "confidence": 0.3842569,
#           "lexical": "it's ok yourself",
#           "itn": "it's ok yourself",
#           "maskedITN": "it's ok yourself",
#           "display": "it's OK yourself"
#         },
#         {
#           "confidence": 0.72042286,
#           "lexical": "it's ok",
#           "itn": "it's ok",
#           "maskedITN": "it's ok",
#           "display": "it's OK"
#         },
#         {
#           "confidence": 0.7036647,
#           "lexical": "ok so",
#           "itn": "ok so",
#           "maskedITN": "ok so",
#           "display": "OK so"
#         },
#         {
#           "confidence": 0.38211858,
#           "lexical": "it's okay yourself",
#           "itn": "it's okay yourself",
#           "maskedITN": "it's okay yourself",
#           "display": "it's okay yourself"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT9.76S",
#       "duration": "PT11.52S",
#       "offsetInTicks": 97600000.0,
#       "durationInTicks": 115200000.0,
#       "nBest": [
#         {
#           "confidence": 0.667045,
#           "lexical": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe",
#           "itn": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe",
#           "maskedITN": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe",
#           "display": "Hi, I'm busy and there is only a Kwanzaa. Do you think bribery is more of a problem with a citizen offers and drive and maybe an official demand a bribe?"
#         },
#         {
#           "confidence": 0.657639,
#           "lexical": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive a maybe an official demand a bribe",
#           "itn": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive a maybe an official demand a bribe",
#           "maskedITN": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive a maybe an official demand a bribe",
#           "display": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive a maybe an official demand a bribe"
#         },
#         {
#           "confidence": 0.67273414,
#           "lexical": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive and maybe an official demand a bribe",
#           "itn": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive and maybe an official demand a bribe",
#           "maskedITN": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive and maybe an official demand a bribe",
#           "display": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive and maybe an official demand a bribe"
#         },
#         {
#           "confidence": 0.67001253,
#           "lexical": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive comma be an official demand a bribe",
#           "itn": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive comma be an official demand a bribe",
#           "maskedITN": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive comma be an official demand a bribe",
#           "display": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a citizen offers and drive comma be an official demand a bribe"
#         },
#         {
#           "confidence": 0.6757103,
#           "lexical": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive comma be an official demand a bribe",
#           "itn": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive comma be an official demand a bribe",
#           "maskedITN": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive comma be an official demand a bribe",
#           "display": "hi i'm busy and there is only a kwanzaa do you think bribery is more of a problem with a a citizen offers and drive comma be an official demand a bribe"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT23.79S",
#       "duration": "PT3.16S",
#       "offsetInTicks": 237900000.0,
#       "durationInTicks": 31600000.0,
#       "nBest": [
#         {
#           "confidence": 0.66845775,
#           "lexical": "cornell strongly agree somewhat agree any common",
#           "itn": "cornell strongly agree somewhat agree any common",
#           "maskedITN": "cornell strongly agree somewhat agree any common",
#           "display": "Cornell strongly agree somewhat agree. Any common?"
#         },
#         {
#           "confidence": 0.62008196,
#           "lexical": "cornell strongly agree somewhat agree any commoner",
#           "itn": "cornell strongly agree somewhat agree any commoner",
#           "maskedITN": "cornell strongly agree somewhat agree any commoner",
#           "display": "cornell strongly agree somewhat agree any commoner"
#         },
#         {
#           "confidence": 0.56137294,
#           "lexical": "cornell strongly agree somewhat agree any communicable",
#           "itn": "cornell strongly agree somewhat agree any communicable",
#           "maskedITN": "cornell strongly agree somewhat agree any communicable",
#           "display": "cornell strongly agree somewhat agree any communicable"
#         },
#         {
#           "confidence": 0.6214207,
#           "lexical": "kunal strongly agree somewhat agree any commoner",
#           "itn": "kunal strongly agree somewhat agree any commoner",
#           "maskedITN": "kunal strongly agree somewhat agree any commoner",
#           "display": "kunal strongly agree somewhat agree any commoner"
#         },
#         {
#           "confidence": 0.5626075,
#           "lexical": "kunal strongly agree somewhat agree any communicable",
#           "itn": "kunal strongly agree somewhat agree any communicable",
#           "maskedITN": "kunal strongly agree somewhat agree any communicable",
#           "display": "kunal strongly agree somewhat agree any communicable"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT28.84S",
#       "duration": "PT0.46S",
#       "offsetInTicks": 288400000.0,
#       "durationInTicks": 4600000.0,
#       "nBest": [
#         {
#           "confidence": 0.650849,
#           "lexical": "let's see i'm",
#           "itn": "let's see i'm",
#           "maskedITN": "let's see i'm",
#           "display": "Let's see, I'm."
#         },
#         {
#           "confidence": 0.4587827,
#           "lexical": "let's see america mobile",
#           "itn": "let's see america mobile",
#           "maskedITN": "let's see america mobile",
#           "display": "let's see america mobile"
#         },
#         {
#           "confidence": 0.48711628,
#           "lexical": "to see america mobile",
#           "itn": "to see america mobile",
#           "maskedITN": "to see america mobile",
#           "display": "to see america mobile"
#         },
#         {
#           "confidence": 0.6456843,
#           "lexical": "let's see",
#           "itn": "let's see",
#           "maskedITN": "let's see",
#           "display": "let's see"
#         },
#         {
#           "confidence": 0.6156372,
#           "lexical": "let's see umm",
#           "itn": "let's see umm",
#           "maskedITN": "let's see umm",
#           "display": "let's see umm"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT30.71S",
#       "duration": "PT3.37S",
#       "offsetInTicks": 307100000.0,
#       "durationInTicks": 33700000.0,
#       "nBest": [
#         {
#           "confidence": 0.6129742,
#           "lexical": "OK yeah it's not strongly agree somewhat agree",
#           "itn": "OK yeah it's not strongly agree somewhat agree",
#           "maskedITN": "ok yeah it's not strongly agree somewhat agree",
#           "display": "OK. Yeah. It's not strongly agree, somewhat agree."
#         },
#         {
#           "confidence": 0.60970545,
#           "lexical": "ok yeah it's now strongly agree somewhat agree",
#           "itn": "ok yeah it's now strongly agree somewhat agree",
#           "maskedITN": "ok yeah it's now strongly agree somewhat agree",
#           "display": "OK yeah it's now strongly agree somewhat agree"
#         },
#         {
#           "confidence": 0.6121539,
#           "lexical": "ok yeah it's not strongly agree somewhat agree yeah",
#           "itn": "ok yeah it's not strongly agree somewhat agree yeah",
#           "maskedITN": "ok yeah it's not strongly agree somewhat agree yeah",
#           "display": "OK yeah it's not strongly agree somewhat agree yeah"
#         },
#         {
#           "confidence": 0.6196075,
#           "lexical": "ok yeah it's not strongly agree somewhat agree and",
#           "itn": "ok yeah it's not strongly agree somewhat agree and",
#           "maskedITN": "ok yeah it's not strongly agree somewhat agree and",
#           "display": "OK yeah it's not strongly agree somewhat agree and"
#         },
#         {
#           "confidence": 0.60913044,
#           "lexical": "ok yeah it's now strongly agree somewhat agree yeah",
#           "itn": "ok yeah it's now strongly agree somewhat agree yeah",
#           "maskedITN": "ok yeah it's now strongly agree somewhat agree yeah",
#           "display": "OK yeah it's now strongly agree somewhat agree yeah"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT35.63S",
#       "duration": "PT1.17S",
#       "offsetInTicks": 356300000.0,
#       "durationInTicks": 11700000.0,
#       "nBest": [
#         {
#           "confidence": 0.71213555,
#           "lexical": "that'd be a lot",
#           "itn": "that'd be a lot",
#           "maskedITN": "that'd be a lot",
#           "display": "That'd be a lot."
#         },
#         {
#           "confidence": 0.7079448,
#           "lexical": "that'd be",
#           "itn": "that'd be",
#           "maskedITN": "that'd be",
#           "display": "that'd be"
#         },
#         {
#           "confidence": 0.6220248,
#           "lexical": "that be",
#           "itn": "that be",
#           "maskedITN": "that be",
#           "display": "that be"
#         },
#         {
#           "confidence": 0.6255087,
#           "lexical": "that'll be all",
#           "itn": "that'll be all",
#           "maskedITN": "that'll be all",
#           "display": "that'll be all"
#         },
#         {
#           "confidence": 0.64674854,
#           "lexical": "that'll be",
#           "itn": "that'll be",
#           "maskedITN": "that'll be",
#           "display": "that'll be"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT38.7S",
#       "duration": "PT0.77S",
#       "offsetInTicks": 387000000.0,
#       "durationInTicks": 7700000.0,
#       "nBest": [
#         {
#           "confidence": 0.7699923,
#           "lexical": "and as i am there",
#           "itn": "and as i am there",
#           "maskedITN": "and as i am there",
#           "display": "And as I am there."
#         },
#         {
#           "confidence": 0.70660007,
#           "lexical": "and as i am calling you now",
#           "itn": "and as i am calling you now",
#           "maskedITN": "and as i am calling you now",
#           "display": "and as i am calling you now"
#         },
#         {
#           "confidence": 0.8144058,
#           "lexical": "and as i am",
#           "itn": "and as i am",
#           "maskedITN": "and as i am",
#           "display": "and as i am"
#         },
#         {
#           "confidence": 0.7248223,
#           "lexical": "and as i am good",
#           "itn": "and as i am good",
#           "maskedITN": "and as i am good",
#           "display": "and as i am good"
#         },
#         {
#           "confidence": 0.64746964,
#           "lexical": "and as i'm there",
#           "itn": "and as i'm there",
#           "maskedITN": "and as i'm there",
#           "display": "and as i'm there"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT41.02S",
#       "duration": "PT10.13S",
#       "offsetInTicks": 410200000.0,
#       "durationInTicks": 101300000.0,
#       "nBest": [
#         {
#           "confidence": 0.7465381,
#           "lexical": "and you will pay it's OK so you apply you apply to every every question now compared to choices you strongly agree somewhat agree",
#           "itn": "and you will pay it's OK so you apply you apply to every every question now compared to choices you strongly agree somewhat agree",
#           "maskedITN": "and you will pay it's ok so you apply you apply to every every question now compared to choices you strongly agree somewhat agree",
#           "display": "And you will pay. It's OK. So you apply. You apply to every every question. Now, compared to choices, you strongly agree. Somewhat agree."
#         },
#         {
#           "confidence": 0.7569802,
#           "lexical": "and you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "itn": "and you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "maskedITN": "and you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "display": "and you will pay it's OK so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree"
#         },
#         {
#           "confidence": 0.7449601,
#           "lexical": "you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "itn": "you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "maskedITN": "you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "display": "you will pay it's OK so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree"
#         },
#         {
#           "confidence": 0.754828,
#           "lexical": "but you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "itn": "but you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "maskedITN": "but you will pay it's ok so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree",
#           "display": "but you will pay it's OK so you apply you can apply to every every question now compared to choices you strongly agree somewhat agree"
#         },
#         {
#           "confidence": 0.7502486,
#           "lexical": "and you will pay it's ok so you apply you can apply to every every question that compared to choices you strongly agree somewhat agree",
#           "itn": "and you will pay it's ok so you apply you can apply to every every question that compared to choices you strongly agree somewhat agree",
#           "maskedITN": "and you will pay it's ok so you apply you can apply to every every question that compared to choices you strongly agree somewhat agree",
#           "display": "and you will pay it's OK so you apply you can apply to every every question that compared to choices you strongly agree somewhat agree"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT52.68S",
#       "duration": "PT1S",
#       "offsetInTicks": 526800000.0,
#       "durationInTicks": 10000000.0,
#       "nBest": [
#         {
#           "confidence": 0.4769133,
#           "lexical": "boca chica hachi",
#           "itn": "boca chica hachi",
#           "maskedITN": "boca chica hachi",
#           "display": "Boca Chica hachi."
#         },
#         {
#           "confidence": 0.46842626,
#           "lexical": "boca chica achi",
#           "itn": "boca chica achi",
#           "maskedITN": "boca chica achi",
#           "display": "boca chica achi"
#         },
#         {
#           "confidence": 0.47008082,
#           "lexical": "boca chica ichi",
#           "itn": "boca chica ichi",
#           "maskedITN": "boca chica ichi",
#           "display": "boca chica ichi"
#         },
#         {
#           "confidence": 0.5048807,
#           "lexical": "boca chica uchi",
#           "itn": "boca chica uchi",
#           "maskedITN": "boca chica uchi",
#           "display": "boca chica uchi"
#         },
#         {
#           "confidence": 0.41052246,
#           "lexical": "boca chica chachi",
#           "itn": "boca chica chachi",
#           "maskedITN": "boca chica chachi",
#           "display": "boca chica chachi"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT55.16S",
#       "duration": "PT7.72S",
#       "offsetInTicks": 551600000.0,
#       "durationInTicks": 77200000.0,
#       "nBest": [
#         {
#           "confidence": 0.60044426,
#           "lexical": "you could do it's OK i'm not gonna come on you do it it's OK so have a you're missing official like demand you",
#           "itn": "you could do it's OK i'm not gonna come on you do it it's OK so have a you're missing official like demand you",
#           "maskedITN": "you could do it's ok i'm not gonna come on you do it it's ok so have a you're missing official like demand you",
#           "display": "You could do. It's OK. I'm not gonna come on. You do it. It's OK. So have a you're missing official like demand you."
#         },
#         {
#           "confidence": 0.60036874,
#           "lexical": "you could do it's ok and i'm not gonna come on you do it it's ok so have a you're missing official like demand you",
#           "itn": "you could do it's ok and i'm not gonna come on you do it it's ok so have a you're missing official like demand you",
#           "maskedITN": "you could do it's ok and i'm not gonna come on you do it it's ok so have a you're missing official like demand you",
#           "display": "you could do it's OK and i'm not gonna come on you do it it's OK so have a you're missing official like demand you"
#         },
#         {
#           "confidence": 0.61576706,
#           "lexical": "you could do it's ok i'm not gonna come on it's ok so have a you're missing official like demand you",
#           "itn": "you could do it's ok i'm not gonna come on it's ok so have a you're missing official like demand you",
#           "maskedITN": "you could do it's ok i'm not gonna come on it's ok so have a you're missing official like demand you",
#           "display": "you could do it's OK i'm not gonna come on it's OK so have a you're missing official like demand you"
#         },
#         {
#           "confidence": 0.6156848,
#           "lexical": "you could do it's ok and i'm not gonna come on it's ok so have a you're missing official like demand you",
#           "itn": "you could do it's ok and i'm not gonna come on it's ok so have a you're missing official like demand you",
#           "maskedITN": "you could do it's ok and i'm not gonna come on it's ok so have a you're missing official like demand you",
#           "display": "you could do it's OK and i'm not gonna come on it's OK so have a you're missing official like demand you"
#         },
#         {
#           "confidence": 0.607728,
#           "lexical": "you could do it's ok i'm not gonna come on do it it's ok so have a you're missing official like demand you",
#           "itn": "you could do it's ok i'm not gonna come on do it it's ok so have a you're missing official like demand you",
#           "maskedITN": "you could do it's ok i'm not gonna come on do it it's ok so have a you're missing official like demand you",
#           "display": "you could do it's OK i'm not gonna come on do it it's OK so have a you're missing official like demand you"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT1M3.7S",
#       "duration": "PT0.18S",
#       "offsetInTicks": 637000000.0,
#       "durationInTicks": 1800000.0,
#       "nBest": [
#         {
#           "confidence": 0.0,
#           "lexical": "",
#           "itn": "",
#           "maskedITN": "",
#           "display": ""
#         },
#         {
#           "confidence": 0.6489016,
#           "lexical": "no",
#           "itn": "no",
#           "maskedITN": "no",
#           "display": "no"
#         },
#         {
#           "confidence": 0.51684946,
#           "lexical": "so",
#           "itn": "so",
#           "maskedITN": "so",
#           "display": "so"
#         },
#         {
#           "confidence": 0.47849706,
#           "lexical": "uh",
#           "itn": "uh",
#           "maskedITN": "uh",
#           "display": "uh"
#         },
#         {
#           "confidence": 0.39196083,
#           "lexical": "yes",
#           "itn": "yes",
#           "maskedITN": "yes",
#           "display": "yes"
#         }
#       ]
#     }
#   ]
# }
# {'values': [{'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/1523b659-109f-465c-9c89-83205dfc3b57/files/204fd831-ab88-4212-b1de-3257f7ff2414', 'name': 'contenturl_0.json', 'kind': 'Transcription', 'properties': {'size': 13421}, 'createdDateTime': '2022-11-25T12:43:13Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/1523b659-109f-465c-9c89-83205dfc3b57_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A46Z&se=2022-11-26T00%3A59%3A46Z&sr=b&sp=rl&sig=OKUYkmraL3P87%2FlKinI0viiIxp5RXUVx5dyQwU8%2FVOc%3D'}}, {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/1523b659-109f-465c-9c89-83205dfc3b57/files/c006f1b9-02bd-4af0-8fa6-0d4cc351e488', 'name': 'report.json', 'kind': 'TranscriptionReport', 'properties': {'size': 399}, 'createdDateTime': '2022-11-25T12:43:13Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/1523b659-109f-465c-9c89-83205dfc3b57_report.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A46Z&se=2022-11-26T00%3A59%3A46Z&sr=b&sp=rl&sig=6UF1mUtby6Cr9U9Hqwt4SoxsYC5296ZVcJWXS9XphJw%3D'}}]}
# https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/1523b659-109f-465c-9c89-83205dfc3b57_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A54%3A46Z&se=2022-11-26T00%3A59%3A46Z&sr=b&sp=rl&sig=OKUYkmraL3P87%2FlKinI0viiIxp5RXUVx5dyQwU8%2FVOc%3D
# {
#   "source": "https://sttttsstorage.blob.core.windows.net/kantaraudios/00000001_silent_424L20-1.mpeg4?sv=2021-06-08&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2022-12-02T20:10:47Z&st=2022-11-25T12:10:47Z&spr=https&sig=alTnZVBhDvhIWknjCCwaDkYtRel26%2FkHOKoTAI2E6iM%3D",
#   "timestamp": "2022-11-25T12:43:13Z",
#   "durationInTicks": 332800000,
#   "duration": "PT33.28S",
#   "combinedRecognizedPhrases": [
#     {
#       "channel": 0,
#       "lexical": "no i agree yeah uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem and maybe it is not OK for citizens to pay bribes because it hurts other people in society before strongly agree for someone OK",
#       "itn": "no i agree yeah uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem and maybe it is not OK for citizens to pay bribes because it hurts other people in society before strongly agree for someone OK",
#       "maskedITN": "no i agree yeah uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem and maybe it is not ok for citizens to pay bribes because it hurts other people in society before strongly agree for someone ok",
#       "display": "No, I agree. Yeah. Uh, do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem? And maybe it is not OK for citizens to pay bribes because it hurts other people in society? Before. Strongly agree. For someone. OK."
#     }
#   ],
#   "recognizedPhrases": [
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT1.05S",
#       "duration": "PT1.95S",
#       "offsetInTicks": 10500000.0,
#       "durationInTicks": 19500000.0,
#       "nBest": [
#         {
#           "confidence": 0.5998723,
#           "lexical": "no i agree",
#           "itn": "no i agree",
#           "maskedITN": "no i agree",
#           "display": "No, I agree."
#         },
#         {
#           "confidence": 0.38361445,
#           "lexical": "no address",
#           "itn": "no address",
#           "maskedITN": "no address",
#           "display": "no address"
#         },
#         {
#           "confidence": 0.66350794,
#           "lexical": "no",
#           "itn": "no",
#           "maskedITN": "no",
#           "display": "no"
#         },
#         {
#           "confidence": 0.22869948,
#           "lexical": "yeah no",
#           "itn": "yeah no",
#           "maskedITN": "yeah no",
#           "display": "yeah no"
#         },
#         {
#           "confidence": 0.34705633,
#           "lexical": "yeah yeah no",
#           "itn": "yeah yeah no",
#           "maskedITN": "yeah yeah no",
#           "display": "yeah yeah no"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT3.26S",
#       "duration": "PT0.18S",
#       "offsetInTicks": 32600000.0,
#       "durationInTicks": 1800000.0,
#       "nBest": [
#         {
#           "confidence": 0.79367924,
#           "lexical": "yeah",
#           "itn": "yeah",
#           "maskedITN": "yeah",
#           "display": "Yeah."
#         },
#         {
#           "confidence": 0.0,
#           "lexical": "",
#           "itn": "",
#           "maskedITN": "",
#           "display": ""
#         },
#         {
#           "confidence": 0.60796285,
#           "lexical": "yep",
#           "itn": "yep",
#           "maskedITN": "yep",
#           "display": "yep"
#         },
#         {
#           "confidence": 0.52300924,
#           "lexical": "yeah yeah",
#           "itn": "yeah yeah",
#           "maskedITN": "yeah yeah",
#           "display": "yeah yeah"
#         },
#         {
#           "confidence": 0.51337683,
#           "lexical": "yes",
#           "itn": "yes",
#           "maskedITN": "yes",
#           "display": "yes"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT5.42S",
#       "duration": "PT13.02S",
#       "offsetInTicks": 54200000.0,
#       "durationInTicks": 130200000.0,
#       "nBest": [
#         {
#           "confidence": 0.854753,
#           "lexical": "uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem and maybe it is not OK for citizens to pay bribes because it hurts other people in society",
#           "itn": "uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem and maybe it is not OK for citizens to pay bribes because it hurts other people in society",
#           "maskedITN": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem and maybe it is not ok for citizens to pay bribes because it hurts other people in society",
#           "display": "Uh, do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem? And maybe it is not OK for citizens to pay bribes because it hurts other people in society?"
#         },
#         {
#           "confidence": 0.8586177,
#           "lexical": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not ok for citizens to pay bribes because it hurts other people in society",
#           "itn": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not ok for citizens to pay bribes because it hurts other people in society",
#           "maskedITN": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not ok for citizens to pay bribes because it hurts other people in society",
#           "display": "uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not OK for citizens to pay bribes because it hurts other people in society"
#         },
#         {
#           "confidence": 0.86694133,
#           "lexical": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm a be it is not ok for citizens to pay bribes because it hurts other people in society",
#           "itn": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm a be it is not ok for citizens to pay bribes because it hurts other people in society",
#           "maskedITN": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm a be it is not ok for citizens to pay bribes because it hurts other people in society",
#           "display": "uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem i'm a be it is not OK for citizens to pay bribes because it hurts other people in society"
#         },
#         {
#           "confidence": 0.85560316,
#           "lexical": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not ok for citizens to pay bribes because it hurts other people and society",
#           "itn": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not ok for citizens to pay bribes because it hurts other people and society",
#           "maskedITN": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not ok for citizens to pay bribes because it hurts other people and society",
#           "display": "uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem i'm abby it is not OK for citizens to pay bribes because it hurts other people and society"
#         },
#         {
#           "confidence": 0.8532106,
#           "lexical": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm away it is not ok for citizens to pay bribes because it hurts other people in society",
#           "itn": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm away it is not ok for citizens to pay bribes because it hurts other people in society",
#           "maskedITN": "uh do you think if it is ok for citizens to pay bribes when it helps them with their own personal problem i'm away it is not ok for citizens to pay bribes because it hurts other people in society",
#           "display": "uh do you think if it is OK for citizens to pay bribes when it helps them with their own personal problem i'm away it is not OK for citizens to pay bribes because it hurts other people in society"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT21.98S",
#       "duration": "PT0.42S",
#       "offsetInTicks": 219800000.0,
#       "durationInTicks": 4200000.0,
#       "nBest": [
#         {
#           "confidence": 0.6781349,
#           "lexical": "before",
#           "itn": "before",
#           "maskedITN": "before",
#           "display": "Before."
#         },
#         {
#           "confidence": 0.4186371,
#           "lexical": "before in",
#           "itn": "before in",
#           "maskedITN": "before in",
#           "display": "before in"
#         },
#         {
#           "confidence": 0.3894375,
#           "lexical": "before you",
#           "itn": "before you",
#           "maskedITN": "before you",
#           "display": "before you"
#         },
#         {
#           "confidence": 0.3823763,
#           "lexical": "before eight",
#           "itn": "before eight",
# ...
#           "maskedITN": "do you think everybody is more of a problem when a citizen offers a briber or when an official demand a bribe",
#           "display": "Do you think everybody is more of a problem when a citizen offers a briber or when an official demand a bribe?"
#         },
#         {
#           "confidence": 0.75150967,
#           "lexical": "do you think everybody is more of a problem when a citizen offers a bright bar or when an official demand a bribe",
#           "itn": "do you think everybody is more of a problem when a citizen offers a bright bar or when an official demand a bribe",
#           "maskedITN": "do you think everybody is more of a problem when a citizen offers a bright bar or when an official demand a bribe",
#           "display": "do you think everybody is more of a problem when a citizen offers a bright bar or when an official demand a bribe"
#         },
#         {
#           "confidence": 0.78037924,
#           "lexical": "do you think everybody is more of a problem when a citizen offers a break or when an official demand a bribe",
#           "itn": "do you think everybody is more of a problem when a citizen offers a break or when an official demand a bribe",
#           "maskedITN": "do you think everybody is more of a problem when a citizen offers a break or when an official demand a bribe",
#           "display": "do you think everybody is more of a problem when a citizen offers a break or when an official demand a bribe"
#         },
#         {
#           "confidence": 0.71649104,
#           "lexical": "do you think everybody is more of a problem when a citizen offers a briber or when an official demand a bride",
#           "itn": "do you think everybody is more of a problem when a citizen offers a briber or when an official demand a bride",
#           "maskedITN": "do you think everybody is more of a problem when a citizen offers a briber or when an official demand a bride",
#           "display": "do you think everybody is more of a problem when a citizen offers a briber or when an official demand a bride"
#         },
#         {
#           "confidence": 0.7699223,
#           "lexical": "do you think everybody is more of a problem when a citizen offers a bright or when an official demand a bribe",
#           "itn": "do you think everybody is more of a problem when a citizen offers a bright or when an official demand a bribe",
#           "maskedITN": "do you think everybody is more of a problem when a citizen offers a bright or when an official demand a bribe",
#           "display": "do you think everybody is more of a problem when a citizen offers a bright or when an official demand a bribe"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT14.22S",
#       "duration": "PT6.99S",
#       "offsetInTicks": 142200000.0,
#       "durationInTicks": 69900000.0,
#       "nBest": [
#         {
#           "confidence": 0.7756609,
#           "lexical": "do you think bribery is more of a problem when a citizen offers a bribe or when an official demands a bribe",
#           "itn": "do you think bribery is more of a problem when a citizen offers a bribe or when an official demands a bribe",
#           "maskedITN": "do you think bribery is more of a problem when a citizen offers a bribe or when an official demands a bribe",
#           "display": "Do you think bribery is more of a problem when a citizen offers a bribe or when an official demands a bribe?"
#         },
#         {
#           "confidence": 0.79420173,
#           "lexical": "do you think bribery is more of a problem when a citizen offers a break or when an official demands a bribe",
#           "itn": "do you think bribery is more of a problem when a citizen offers a break or when an official demands a bribe",
#           "maskedITN": "do you think bribery is more of a problem when a citizen offers a break or when an official demands a bribe",
#           "display": "do you think bribery is more of a problem when a citizen offers a break or when an official demands a bribe"
#         },
#         {
#           "confidence": 0.79094684,
#           "lexical": "do you think bribery is more of a problem when a citizen offers a bride or when an official demands a bribe",
#           "itn": "do you think bribery is more of a problem when a citizen offers a bride or when an official demands a bribe",
#           "maskedITN": "do you think bribery is more of a problem when a citizen offers a bride or when an official demands a bribe",
#           "display": "do you think bribery is more of a problem when a citizen offers a bride or when an official demands a bribe"
#         },
#         {
#           "confidence": 0.7827045,
#           "lexical": "do you think bribery is more of a problem when a citizen offers a bread or when an official demands a bribe",
#           "itn": "do you think bribery is more of a problem when a citizen offers a bread or when an official demands a bribe",
#           "maskedITN": "do you think bribery is more of a problem when a citizen offers a bread or when an official demands a bribe",
#           "display": "do you think bribery is more of a problem when a citizen offers a bread or when an official demands a bribe"
#         },
#         {
#           "confidence": 0.78561497,
#           "lexical": "do you think bribery is more of a problem when a citizen offers a braid or when an official demands a bribe",
#           "itn": "do you think bribery is more of a problem when a citizen offers a braid or when an official demands a bribe",
#           "maskedITN": "do you think bribery is more of a problem when a citizen offers a braid or when an official demands a bribe",
#           "display": "do you think bribery is more of a problem when a citizen offers a braid or when an official demands a bribe"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT22.53S",
#       "duration": "PT2.98S",
#       "offsetInTicks": 225300000.0,
#       "durationInTicks": 29800000.0,
#       "nBest": [
#         {
#           "confidence": 0.725303,
#           "lexical": "unofficial strongly agree i'm a somewhat",
#           "itn": "unofficial strongly agree i'm a somewhat",
#           "maskedITN": "unofficial strongly agree i'm a somewhat",
#           "display": "Unofficial strongly agree I'm a somewhat."
#         },
#         {
#           "confidence": 0.6853785,
#           "lexical": "unofficial strongly agree i'm as somewhat",
#           "itn": "unofficial strongly agree i'm as somewhat",
#           "maskedITN": "unofficial strongly agree i'm as somewhat",
#           "display": "unofficial strongly agree i'm as somewhat"
#         },
#         {
#           "confidence": 0.70295775,
#           "lexical": "unofficial strongly agreed i'm a somewhat",
#           "itn": "unofficial strongly agreed i'm a somewhat",
#           "maskedITN": "unofficial strongly agreed i'm a somewhat",
#           "display": "unofficial strongly agreed i'm a somewhat"
#         },
#         {
#           "confidence": 0.675279,
#           "lexical": "unofficial strongly agree i'm at somewhat",
#           "itn": "unofficial strongly agree i'm at somewhat",
#           "maskedITN": "unofficial strongly agree i'm at somewhat",
#           "display": "unofficial strongly agree i'm at somewhat"
#         },
#         {
#           "confidence": 0.7334061,
#           "lexical": "an official strongly agree i'm a somewhat",
#           "itn": "an official strongly agree i'm a somewhat",
#           "maskedITN": "an official strongly agree i'm a somewhat",
#           "display": "an official strongly agree i'm a somewhat"
#         }
#       ]
#     }
#   ]
# }
# {'values': [{'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/94227e02-3158-47c3-be3d-54789a34c6b4/files/0bc188ad-7fc3-4fdd-ade5-9f28fd0ea8d9', 'name': 'contenturl_0.json', 'kind': 'Transcription', 'properties': {'size': 6789}, 'createdDateTime': '2022-11-25T12:43:36Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/94227e02-3158-47c3-be3d-54789a34c6b4_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A55%3A02Z&se=2022-11-26T01%3A00%3A02Z&sr=b&sp=rl&sig=Zd1l%2FqCiz8IZDtGHkn1yf6KJJAtQ0rUuwkPBkzu1Mfs%3D'}}, {'self': 'https://westeurope.api.cognitive.microsoft.com/speechtotext/v3.0/transcriptions/94227e02-3158-47c3-be3d-54789a34c6b4/files/ceb7239d-1719-4553-901e-f246b4604c20', 'name': 'report.json', 'kind': 'TranscriptionReport', 'properties': {'size': 399}, 'createdDateTime': '2022-11-25T12:43:36Z', 'links': {'contentUrl': 'https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/94227e02-3158-47c3-be3d-54789a34c6b4_report.json?sv=2021-10-04&st=2022-11-25T12%3A55%3A02Z&se=2022-11-26T01%3A00%3A02Z&sr=b&sp=rl&sig=5%2FltI%2FQKfnG8S0ZKKDfljxNViXF2676PuU%2F5R0s9Rwk%3D'}}]}
# https://spsvcprodweu.blob.core.windows.net/bestor-acc02701-cb45-42dc-9d32-2843911017ca/TranscriptionData/94227e02-3158-47c3-be3d-54789a34c6b4_0_0.json?sv=2021-10-04&st=2022-11-25T12%3A55%3A02Z&se=2022-11-26T01%3A00%3A02Z&sr=b&sp=rl&sig=Zd1l%2FqCiz8IZDtGHkn1yf6KJJAtQ0rUuwkPBkzu1Mfs%3D
# {
#   "source": "https://sttttsstorage.blob.core.windows.net/kantaraudios/00000017_silent_424L20-1.mpeg4?sv=2021-06-08&ss=bfqt&srt=sco&sp=rwdlacupiytfx&se=2022-12-02T20:10:47Z&st=2022-11-25T12:10:47Z&spr=https&sig=alTnZVBhDvhIWknjCCwaDkYtRel26%2FkHOKoTAI2E6iM%3D",
#   "timestamp": "2022-11-25T12:43:36Z",
#   "durationInTicks": 145600000,
#   "duration": "PT14.56S",
#   "combinedRecognizedPhrases": [
#     {
#       "channel": 0,
#       "lexical": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem it is not OK it hurts other people after that strongly some",
#       "itn": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem it is not OK it hurts other people after that strongly some",
#       "maskedITN": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem it is not ok it hurts other people after that strongly some",
#       "display": "The next question, do you think it is OK for citizens to pay grades when it helps them with their own personal problem? It is not OK. It hurts other people after that. Strongly some."
#     }
#   ],
#   "recognizedPhrases": [
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT3.06S",
#       "duration": "PT8.21S",
#       "offsetInTicks": 30600000.0,
#       "durationInTicks": 82100000.0,
#       "nBest": [
#         {
#           "confidence": 0.85926175,
#           "lexical": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem it is not OK it hurts other people after that",
#           "itn": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem it is not OK it hurts other people after that",
#           "maskedITN": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem it is not ok it hurts other people after that",
#           "display": "The next question, do you think it is OK for citizens to pay grades when it helps them with their own personal problem? It is not OK. It hurts other people after that."
#         },
#         {
#           "confidence": 0.87031114,
#           "lexical": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people after that",
#           "itn": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people after that",
#           "maskedITN": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people after that",
#           "display": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem and it is not OK it hurts other people after that"
#         },
#         {
#           "confidence": 0.8831921,
#           "lexical": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people are so hard",
#           "itn": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people are so hard",
#           "maskedITN": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people are so hard",
#           "display": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem and it is not OK it hurts other people are so hard"
#         },
#         {
#           "confidence": 0.8910595,
#           "lexical": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people as well",
#           "itn": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people as well",
#           "maskedITN": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem and it is not ok it hurts other people as well",
#           "display": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem and it is not OK it hurts other people as well"
#         },
#         {
#           "confidence": 0.87203526,
#           "lexical": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem it is not ok it hurts other people are so hard",
#           "itn": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem it is not ok it hurts other people are so hard",
#           "maskedITN": "the next question do you think it is ok for citizens to pay grades when it helps them with their own personal problem it is not ok it hurts other people are so hard",
#           "display": "the next question do you think it is OK for citizens to pay grades when it helps them with their own personal problem it is not OK it hurts other people are so hard"
#         }
#       ]
#     },
#     {
#       "recognitionStatus": "Success",
#       "channel": 0,
#       "offset": "PT13.83S",
#       "duration": "PT0.69S",
#       "offsetInTicks": 138300000.0,
#       "durationInTicks": 6900000.0,
#       "nBest": [
#         {
#           "confidence": 0.44564378,
#           "lexical": "strongly some",
#           "itn": "strongly some",
#           "maskedITN": "strongly some",
#           "display": "Strongly some."
#         },
#         {
#           "confidence": 0.5647243,
#           "lexical": "strongly",
#           "itn": "strongly",
#           "maskedITN": "strongly",
#           "display": "strongly"
#         },
#         {
#           "confidence": 0.45773587,
#           "lexical": "strong with some",
#           "itn": "strong with some",
#           "maskedITN": "strong with some",
#           "display": "strong with some"
#         },
#         {
#           "confidence": 0.4375139,
#           "lexical": "strongly so",
#           "itn": "strongly so",
#           "maskedITN": "strongly so",
#           "display": "strongly so"
#         },
#         {
#           "confidence": 0.25126064,
#           "lexical": "strongly come",
#           "itn": "strongly come",
#           "maskedITN": "strongly come",
#           "display": "strongly come"
#         }
#       ]
#     }
#   ]
# }

# %% [markdown]
# ## Truncate the transcriptions log

# %%
x = "365ebfde-0ae0-43f8-8f9a-90feea3f54b2"

# %%
headers = {"Ocp-Apim-Subscription-Key": SUBSCRIPTION_KEY}
r = requests.delete(BaseURL+x, headers=headers)

# %%
r.text
# Out:
# '{\n  "code": "InvalidRequest",\n  "message": "The transcription can\'t be deleted, because it is referenced by an accuracy test.",\n  "innerError": {\n    "code": "DeleteNotAllowed",\n    "message": "The transcription can\'t be deleted, because it is referenced by an accuracy test."\n  }\n}'

# %%
def deleteAllTranscriptions() :
    trs=listAllTranscriptions()
    for x in trs["id"] :
        print(x)
        headers = {"Ocp-Apim-Subscription-Key": SUBSCRIPTION_KEY}
        r = requests.delete(BaseURL+x, headers=headers)
        print(r)

# %%
deleteAllTranscriptions()
# Out:
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# C:\Users\faismali\AppData\Local\Temp\ipykernel_53496\2131517670.py:13: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({
# 365ebfde-0ae0-43f8-8f9a-90feea3f54b2
# <Response [400]>
# 80d7bdcd-95e8-403c-a752-98b61bb5fac7
# <Response [400]>
# 2f28a43a-6712-4779-abcc-aca875193870
# <Response [400]>
# eb472bbe-65ca-4166-9900-ffb4fc9e2f44
# <Response [400]>
# e80e1577-879c-488a-a436-361944569a93
# <Response [400]>
# be61e095-b7a8-467c-b088-49fb81e6b86d
# <Response [400]>
# 5681e251-3740-445f-9398-9f066273e8d1
# <Response [400]>
# 970dc9c5-a66b-4095-92db-6a9e171f47c1
# <Response [400]>
# b12414bb-0ba1-4572-b6f5-2c10dd03a38b
# <Response [204]>
# 2dce3fed-43bd-45aa-831c-a042ef6c6568
# <Response [204]>
# d43f7a60-7e18-4e6f-a4a3-f9939740b9b1
# <Response [204]>
# 06424e44-c0ad-4900-8c12-4be1fa74261e
# <Response [204]>
# aed013c2-eb82-4a75-bb98-c18e3c7618ed
# <Response [204]>

# %% [markdown]
# ## Obtain sentiment scores using Text Analytics for each of the utterances from the transcription

# %%
headers = {"Ocp-Apim-Subscription-Key": SUBSCRIPTION_KEY}
r = requests.get(json.loads(data)['values'][0]['links']['contentUrl'], headers=headers)
json_text = json.loads(r.text)

# %%
for val in jsonobj['values']:
    if val['kind'] == 'Transcription':
        contentUrl = val['links']['contentUrl']
    print(contentUrl)
    r = requests.get(contentUrl, headers=headers)
    json_text = json.loads(r.text)

# %%
json_text['combinedRecognizedPhrases'][0]['display']

# %%
TEXT_SUBSCRIPTION_KEY = ""
## Text to Speech region
region = "westeurope"

# %%
text_headers = {
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': TEXT_SUBSCRIPTION_KEY,
}

text_params = urllib.parse.urlencode({
    # Request parameters
})

docs = {"documents": [
           {
               "language": "en",
               "id" : "1",
               "text": json_text['combinedRecognizedPhrases'][0]['display']
               
           }
]}


try:
    conn = http.client.HTTPSConnection(region + '.api.cognitive.microsoft.com')
    conn.request("POST", "/text/analytics/v3.1/sentiment?%s" % text_params, json.dumps(docs), text_headers)
    response = conn.getresponse()
    data = response.read()
    
    conn.close()
except Exception as e:
    print("[Errno {0}] {1}".format(e.errno, e.strerror))

# %%
json.loads(data)
